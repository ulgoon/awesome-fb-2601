# %%
['fizz'*(i%3==0) + 'buzz'*(i%5==0) or i for i in range(1, 15+1)]
# Out:
# [1,
#  2,
#  'fizz',
#  4,
#  'buzz',
#  'fizz',
#  7,
#  8,
#  'fizz',
#  'buzz',
#  11,
#  'fizz',
#  13,
#  14,
#  'fizzbuzz']

# %%
print('haha')
# Out:
# haha
